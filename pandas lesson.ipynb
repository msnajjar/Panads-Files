# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\000\eyouth\DA_Main.csv")

# %%
data
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 0        1       H-43  22/11/2020    Back Light    Jeep      USA      Mohamed
# 1        2       L-81  08/08/2020  Back Bumpers     GMC      USA        Amgad
# 2        3       R-86  29/07/2019      Spoilers  Toyota    Japan         Hany
# 3        4       X-47  16/11/2020   Front Light    Audi  Germany       Yasser
# 4        5       B-69  24/04/2020      Back Led  Nissan    Japan        Islam
# ...    ...        ...         ...           ...     ...      ...          ...
# 4995  4996       A-28  03/08/2020   Front Light    Ford      USA       Yasser
# 4996  4997       J-73  12/08/2020  Front Bumper    Audi  Germany        Amgad
# 4997  4998       Q-79  25/02/2020      Body kit    Ford      USA      Mohamed
# 4998  4999       N-13  30/08/2020         Rings    Audi  Germany        Amgad
# 4999  5000       U-22  19/01/2020      Back Led  Nissan    Japan        Amgad
#
# ...

# %%
data.head(10)
# Out:
#    s/no invoice no        date          product  Brands  country sales Person  \
# 0     1       H-43  22/11/2020       Back Light    Jeep      USA      Mohamed
# 1     2       L-81  08/08/2020     Back Bumpers     GMC      USA        Amgad
# 2     3       R-86  29/07/2019         Spoilers  Toyota    Japan         Hany
# 3     4       X-47  16/11/2020      Front Light    Audi  Germany       Yasser
# 4     5       B-69  24/04/2020         Back Led  Nissan    Japan        Islam
# 5     6       X-23  20/07/2020        Front Led   Mazda    Japan        Amgad
# 6     7       V-40  17/11/2019  Steering wheels     BMW  Germany        Ahmed
# 7     8       Q-21  14/10/2020         Back Led     BMW  Germany      Mostafa
# 8     9       G-76  27/02/2019       Back Light  Toyota    Japan        Amgad
# 9    10       X-80  01/06/2019       Back Light   Mazda    Japan      Mostafa
#
#        branch         mobile        customers  qty  price  total  discount  \
# ...

# %%
data.tail(10)
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 4990  4991       V-51  27/05/2020  Back Bumpers    Opel  Germany        Amgad
# 4991  4992       R-43  17/12/2019     Front Led    Ford      USA        Ahmed
# 4992  4993       D-86  08/06/2019      Back Fog    Opel  Germany       Yasser
# 4993  4994       C-51  02/03/2019         Rings   Honda    Japan       Yasser
# 4994  4995       C-92  20/09/2020      Back Fog  Toyota    Japan        Islam
# 4995  4996       A-28  03/08/2020   Front Light    Ford      USA       Yasser
# 4996  4997       J-73  12/08/2020  Front Bumper    Audi  Germany        Amgad
# 4997  4998       Q-79  25/02/2020      Body kit    Ford      USA      Mohamed
# 4998  4999       N-13  30/08/2020         Rings    Audi  Germany        Amgad
# 4999  5000       U-22  19/01/2020      Back Led  Nissan    Japan        Amgad
#
#           branch         mobile     customers  qty  price  total  discount  \
# ...

# %%
data_df=  pd.read_csv(r"C:\000\eyouth\DA_Main.csv")

# %%
data_df.shape
# Out:
# (5000, 15)

# %%
data_df.shape[0]
# Out:
# 5000

# %%
data_df.shape[1]
# Out:
# 15

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   s/no          5000 non-null   int64
#  1   invoice no    5000 non-null   object
#  2   date          5000 non-null   object
#  3   product       5000 non-null   object
#  4   Brands        5000 non-null   object
#  5   country       5000 non-null   object
#  6   sales Person  5000 non-null   object
#  7   branch        5000 non-null   object
#  8   mobile        5000 non-null   object
#  9   customers     5000 non-null   object
#  10  qty           5000 non-null   int64
#  11  price         5000 non-null   float64
#  12  total         5000 non-null   int64
#  13  discount      5000 non-null   int64
#  14  net sales     5000 non-null   int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 586.1+ KB

# %%
data.describe()
# Out:
#               s/no          qty       price        total     discount  \
# count  5000.000000  5000.000000  5000.00000  5000.000000  5000.000000
# mean   2500.500000     5.514400   230.31400  1269.313400    97.890000
# std    1443.520003     2.904183    72.55791   803.925099    83.116963
# min       1.000000     1.000000   101.00000   101.000000     0.000000
# 25%    1250.750000     3.000000   173.00000   624.000000    50.000000
# 50%    2500.500000     5.000000   235.00000  1140.000000   100.000000
# 75%    3750.250000     8.000000   301.00000  1809.250000   100.000000
# max    5000.000000    10.000000   350.00000  3500.000000   250.000000
#
#         net sales
# count  5000.00000
# mean   1171.54380
# std     726.77066
# min     101.00000
# 25%     574.00000
# 50%    1040.00000
# 75%    1709.25000
# max    3250.00000

# %%
data.describe(include="all")
# Out:
#                s/no invoice no        date    product Brands country  \
# count   5000.000000       5000        5000       5000   5000    5000
# unique          NaN       2206         731         13     10       3
# top             NaN       P-56  01/04/2019  Front Fog   Audi   Japan
# freq            NaN          9          15        415    547    1870
# mean    2500.500000        NaN         NaN        NaN    NaN     NaN
# std     1443.520003        NaN         NaN        NaN    NaN     NaN
# min        1.000000        NaN         NaN        NaN    NaN     NaN
# 25%     1250.750000        NaN         NaN        NaN    NaN     NaN
# 50%     2500.500000        NaN         NaN        NaN    NaN     NaN
# 75%     3750.250000        NaN         NaN        NaN    NaN     NaN
# max     5000.000000        NaN         NaN        NaN    NaN     NaN
#
#        sales Person branch         mobile customers          qty       price  \
# ...

# %%
data.country.describe()
# Out:
# count      5000
# unique        3
# top       Japan
# freq       1870
# Name: country, dtype: object

# %%
data.qty.describe()
# Out:
# count    5000.000000
# mean        5.514400
# std         2.904183
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: qty, dtype: float64

# %%
data.qty.sum()
# Out:
# 27572

# %%
round(data.qty.mean())
# Out:
# 6

# %%
data.Brands
# Out:
# 0         Jeep
# 1          GMC
# 2       Toyota
# 3         Audi
# 4       Nissan
#          ...
# 4995      Ford
# 4996      Audi
# 4997      Ford
# 4998      Audi
# 4999    Nissan
# Name: Brands, Length: 5000, dtype: object

# %%
data.Brands.unique()
# Out:
# array(['Jeep', 'GMC', 'Toyota', 'Audi', 'Nissan', 'Mazda', 'BMW', 'Opel',
#        'Honda', 'Ford'], dtype=object)

# %%
data.Brands.value_counts()
# Out:
# Brands
# Audi      547
# BMW       535
# Opel      524
# Jeep      517
# Ford      517
# GMC       490
# Nissan    477
# Mazda     472
# Toyota    469
# Honda     452
# Name: count, dtype: int64

# %%
data['branch'].value_counts()
# Out:
# branch
# Luxur         1067
# Hurghada      1024
# Tanta         1002
# Alexandria     960
# Cairo          947
# Name: count, dtype: int64

# %%
data['sales Person'].value_counts()
# Out:
# sales Person
# Mohamed    733
# Ahmed      724
# Mostafa    723
# Amgad      714
# Islam      709
# Hany       699
# Yasser     698
# Name: count, dtype: int64

# %%
data['customers']
# Out:
# 0        Nissan Egypt
# 1             Zezinia
# 2           Egypt Air
# 3       Luxur Holding
# 4          Almorshedy
#             ...
# 4995          Shifeld
# 4996               We
# 4997     Bavarian com
# 4998           Lepton
# 4999           Carmen
# Name: customers, Length: 5000, dtype: object

# %%
data[["customers",'branch',"qty",'sales Person']]
# Out:
#           customers      branch  qty sales Person
# 0      Nissan Egypt  Alexandria    9      Mohamed
# 1           Zezinia       Tanta    7        Amgad
# 2         Egypt Air    Hurghada    6         Hany
# 3     Luxur Holding  Alexandria    1       Yasser
# 4        Almorshedy       Tanta    7        Islam
# ...             ...         ...  ...          ...
# 4995        Shifeld       Cairo   10       Yasser
# 4996             We  Alexandria    3        Amgad
# 4997   Bavarian com       Luxur    9      Mohamed
# 4998         Lepton    Hurghada    4        Amgad
# 4999         Carmen       Cairo    1        Amgad
#
# [5000 rows x 4 columns]

# %%
data['revenue']= data['qty'] * data['price']

# %%
data
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 0        1       H-43  22/11/2020    Back Light    Jeep      USA      Mohamed
# 1        2       L-81  08/08/2020  Back Bumpers     GMC      USA        Amgad
# 2        3       R-86  29/07/2019      Spoilers  Toyota    Japan         Hany
# 3        4       X-47  16/11/2020   Front Light    Audi  Germany       Yasser
# 4        5       B-69  24/04/2020      Back Led  Nissan    Japan        Islam
# ...    ...        ...         ...           ...     ...      ...          ...
# 4995  4996       A-28  03/08/2020   Front Light    Ford      USA       Yasser
# 4996  4997       J-73  12/08/2020  Front Bumper    Audi  Germany        Amgad
# 4997  4998       Q-79  25/02/2020      Body kit    Ford      USA      Mohamed
# 4998  4999       N-13  30/08/2020         Rings    Audi  Germany        Amgad
# 4999  5000       U-22  19/01/2020      Back Led  Nissan    Japan        Amgad
#
# ...

# %%
data.sort_values(by = "revenue")
# Out:
#       s/no invoice no        date       product Brands  country sales Person  \
# 2919  2920       Q-56  23/12/2019         Rings   Opel  Germany         Hany
# 1434  1435       S-15  23/12/2020         Rings   Opel  Germany         Hany
# 3631  3632       C-65  29/07/2020    Back Light   Jeep      USA      Mohamed
# 4744  4745       K-60  03/12/2020    Back Light   Jeep      USA        Amgad
# 4252  4253       P-90  25/04/2019    Back Light   Jeep      USA        Ahmed
# ...    ...        ...         ...           ...    ...      ...          ...
# 3332  3333        U-3  30/11/2020  Back Bumpers   Opel  Germany        Amgad
# 10      11       I-91  12/08/2020  Back Bumpers   Opel  Germany      Mostafa
# 2192  2193       B-39  14/01/2019  Back Bumpers   Opel  Germany      Mostafa
# 1417  1418       D-65  30/04/2020  Back Bumpers   Opel  Germany         Hany
# 4990  4991       V-51  27/05/2020  Back Bumpers   Opel  Germany        Amgad
#
# ...

# %%
data.sort_values(by = "revenue" , ascending= False )
# Out:
#       s/no invoice no        date       product Brands  country sales Person  \
# 3332  3333        U-3  30/11/2020  Back Bumpers   Opel  Germany        Amgad
# 1417  1418       D-65  30/04/2020  Back Bumpers   Opel  Germany         Hany
# 2192  2193       B-39  14/01/2019  Back Bumpers   Opel  Germany      Mostafa
# 4990  4991       V-51  27/05/2020  Back Bumpers   Opel  Germany        Amgad
# 10      11       I-91  12/08/2020  Back Bumpers   Opel  Germany      Mostafa
# ...    ...        ...         ...           ...    ...      ...          ...
# 4744  4745       K-60  03/12/2020    Back Light   Jeep      USA        Amgad
# 3631  3632       C-65  29/07/2020    Back Light   Jeep      USA      Mohamed
# 4252  4253       P-90  25/04/2019    Back Light   Jeep      USA        Ahmed
# 2919  2920       Q-56  23/12/2019         Rings   Opel  Germany         Hany
# 1434  1435       S-15  23/12/2020         Rings   Opel  Germany         Hany
#
# ...

# %%
data.sort_values(by = "customers" , ascending= False ).head(15)
# Out:
#       s/no invoice no        date          product  Brands  country  \
# 2352  2353       I-98  23/09/2019         Back Fog   Honda    Japan
# 2564  2565       V-91  06/12/2020         Spoilers     GMC      USA
# 4676  4677       U-15  08/02/2020             Logo     GMC      USA
# 4162  4163        H-2  21/12/2019         Back Fog    Opel  Germany
# 407    408       W-77  17/02/2019     Back Bumpers    Opel  Germany
# 4453  4454       G-82  28/07/2020       Back Light     BMW  Germany
# 1866  1867       B-43  24/04/2019      Front Light  Toyota    Japan
# 2666  2667       Y-61  30/04/2020        Front Led    Audi  Germany
# 2437  2438       W-84  27/10/2019         Back Led     GMC      USA
# 1112  1113       J-58  23/03/2019         Spoilers    Opel  Germany
# 4441  4442        W-1  10/12/2019     Back Bumpers    Jeep      USA
# 4612  4613       N-29  18/02/2020             Logo    Audi  Germany
# 2952  2953       X-93  14/07/2019         Back Fog   Honda    Japan
# ...

# %%
data.columns
# Out:
# Index(['s/no', 'invoice no', 'date', 'product', 'Brands', 'country',
#        'sales Person', 'branch', 'mobile', 'customers', 'qty', 'price',
#        'total', 'discount', 'net sales', 'revenue'],
#       dtype='object')

# %%
data.columns[10]
# Out:
# 'qty'

# %%
data.columns[10][2]
# Out:
# 'y'

# %%
data.values[10][2]
# Out:
# '12/08/2020'

# %%
data[10:11]
# Out:
#     s/no invoice no        date          product  Brands  country  \
# 0      1       H-43  22/11/2020       Back Light    Jeep      USA
# 1      2       L-81  08/08/2020     Back Bumpers     GMC      USA
# 2      3       R-86  29/07/2019         Spoilers  Toyota    Japan
# 3      4       X-47  16/11/2020      Front Light    Audi  Germany
# 4      5       B-69  24/04/2020         Back Led  Nissan    Japan
# 5      6       X-23  20/07/2020        Front Led   Mazda    Japan
# 6      7       V-40  17/11/2019  Steering wheels     BMW  Germany
# 7      8       Q-21  14/10/2020         Back Led     BMW  Germany
# 8      9       G-76  27/02/2019       Back Light  Toyota    Japan
# 9     10       X-80  01/06/2019       Back Light   Mazda    Japan
# 10    11       I-91  12/08/2020     Back Bumpers    Opel  Germany
# 11    12       W-44  11/11/2019  Steering wheels    Audi  Germany
# 12    13       Z-10  26/05/2019         Back Fog     GMC      USA
# ...

# %%
data[10:15]
# Out:
#     s/no invoice no        date          product Brands  country sales Person  \
# 10    11       I-91  12/08/2020     Back Bumpers   Opel  Germany      Mostafa
# 11    12       W-44  11/11/2019  Steering wheels   Audi  Germany      Mostafa
# 12    13       Z-10  26/05/2019         Back Fog    GMC      USA      Mohamed
# 13    14       X-66  24/08/2019         Body kit  Honda    Japan      Mostafa
# 14    15       J-90  27/05/2020         Back Led   Jeep      USA      Mohamed
#
#         branch         mobile      customers  qty  price  total  discount  \
# 10       Tanta  012 - 6882303           Mega   10  350.0   3500       250
# 11       Luxur  011 - 6452609         B.teck    5  338.0   1690       100
# 12       Tanta   015 - 832291     Cearrifour    2  187.0    374         0
# 13  Alexandria  011 - 4328668  Egypt Holding   10  219.0   2190       250
# 14       Luxur  012 - 7861612  Luxur Holding    8  278.0   2224       250
#
#     net sales  revenue
# 10       3250   3500.0
# ...

# %%
data[:15]
# Out:
#     s/no invoice no        date          product  Brands  country  \
# 0      1       H-43  22/11/2020       Back Light    Jeep      USA
# 1      2       L-81  08/08/2020     Back Bumpers     GMC      USA
# 2      3       R-86  29/07/2019         Spoilers  Toyota    Japan
# 3      4       X-47  16/11/2020      Front Light    Audi  Germany
# 4      5       B-69  24/04/2020         Back Led  Nissan    Japan
# 5      6       X-23  20/07/2020        Front Led   Mazda    Japan
# 6      7       V-40  17/11/2019  Steering wheels     BMW  Germany
# 7      8       Q-21  14/10/2020         Back Led     BMW  Germany
# 8      9       G-76  27/02/2019       Back Light  Toyota    Japan
# 9     10       X-80  01/06/2019       Back Light   Mazda    Japan
# 10    11       I-91  12/08/2020     Back Bumpers    Opel  Germany
# 11    12       W-44  11/11/2019  Steering wheels    Audi  Germany
# 12    13       Z-10  26/05/2019         Back Fog     GMC      USA
# ...

# %%
data[4984:]
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 4984  4985        Q-7  09/08/2019  Back Bumpers     GMC      USA        Amgad
# 4985  4986       D-47  01/04/2019     Front Fog    Ford      USA      Mostafa
# 4986  4987       P-46  22/01/2020     Front Led    Jeep      USA        Ahmed
# 4987  4988       W-86  12/07/2020      Back Fog     GMC      USA       Yasser
# 4988  4989       Q-14  29/08/2020      Spoilers    Opel  Germany      Mohamed
# 4989  4990       J-31  21/06/2019      Back Led    Opel  Germany         Hany
# 4990  4991       V-51  27/05/2020  Back Bumpers    Opel  Germany        Amgad
# 4991  4992       R-43  17/12/2019     Front Led    Ford      USA        Ahmed
# 4992  4993       D-86  08/06/2019      Back Fog    Opel  Germany       Yasser
# 4993  4994       C-51  02/03/2019         Rings   Honda    Japan       Yasser
# 4994  4995       C-92  20/09/2020      Back Fog  Toyota    Japan        Islam
# ...

# %%
data.drop_duplicates('product')
# Out:
#     s/no invoice no        date          product  Brands  country  \
# 0      1       H-43  22/11/2020       Back Light    Jeep      USA
# 1      2       L-81  08/08/2020     Back Bumpers     GMC      USA
# 2      3       R-86  29/07/2019         Spoilers  Toyota    Japan
# 3      4       X-47  16/11/2020      Front Light    Audi  Germany
# 4      5       B-69  24/04/2020         Back Led  Nissan    Japan
# 5      6       X-23  20/07/2020        Front Led   Mazda    Japan
# 6      7       V-40  17/11/2019  Steering wheels     BMW  Germany
# 12    13       Z-10  26/05/2019         Back Fog     GMC      USA
# 13    14       X-66  24/08/2019         Body kit   Honda    Japan
# 16    17       F-10  16/03/2020            Rings     GMC      USA
# 19    20       Z-55  27/11/2019        Front Fog    Opel  Germany
# 29    30       F-42  30/06/2020             Logo    Opel  Germany
# 32    33       V-81  07/05/2020     Front Bumper    Ford      USA
#
# ...

# %%
data.drop_duplicates(['product','Brands'])
# Out:
#      s/no invoice no        date       product  Brands  country sales Person  \
# 0       1       H-43  22/11/2020    Back Light    Jeep      USA      Mohamed
# 1       2       L-81  08/08/2020  Back Bumpers     GMC      USA        Amgad
# 2       3       R-86  29/07/2019      Spoilers  Toyota    Japan         Hany
# 3       4       X-47  16/11/2020   Front Light    Audi  Germany       Yasser
# 4       5       B-69  24/04/2020      Back Led  Nissan    Japan        Islam
# ..    ...        ...         ...           ...     ...      ...          ...
# 441   442       C-62  10/01/2020  Front Bumper    Opel  Germany        Islam
# 460   461       W-74  07/02/2020     Front Led    Opel  Germany      Mostafa
# 507   508       D-90  31/05/2019      Spoilers    Opel  Germany        Ahmed
# 778   779       I-99  17/07/2020      Body kit   Mazda    Japan        Islam
# 826   827       G-49  11/05/2019   Front Light   Honda    Japan         Hany
#
# ...

# %%
data.query('qty > 9')
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 8        9       G-76  27/02/2019    Back Light  Toyota    Japan        Amgad
# 10      11       I-91  12/08/2020  Back Bumpers    Opel  Germany      Mostafa
# 13      14       X-66  24/08/2019      Body kit   Honda    Japan      Mostafa
# 46      47       X-66  22/11/2019      Back Led   Honda    Japan      Mostafa
# 63      64       P-81  31/10/2019      Spoilers    Audi  Germany      Mostafa
# ...    ...        ...         ...           ...     ...      ...          ...
# 4946  4947       F-67  22/11/2020      Back Fog    Ford      USA      Mostafa
# 4952  4953       W-59  29/01/2020          Logo  Nissan    Japan        Amgad
# 4973  4974       Z-65  25/10/2020  Front Bumper     BMW  Germany      Mohamed
# 4990  4991       V-51  27/05/2020  Back Bumpers    Opel  Germany        Amgad
# 4995  4996       A-28  03/08/2020   Front Light    Ford      USA       Yasser
#
# ...

# %%
data[(data['branch'] == "Cairo")]
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 9       10       X-80  01/06/2019    Back Light   Mazda    Japan      Mostafa
# 20      21        T-9  29/01/2019     Front Led     BMW  Germany        Amgad
# 26      27       S-85  28/03/2020     Front Led  Toyota    Japan        Ahmed
# 33      34       O-86  28/10/2020      Back Led    Ford      USA       Yasser
# 34      35       D-70  10/02/2020  Front Bumper   Honda    Japan        Amgad
# ...    ...        ...         ...           ...     ...      ...          ...
# 4976  4977       C-50  15/01/2020  Back Bumpers   Mazda    Japan      Mostafa
# 4986  4987       P-46  22/01/2020     Front Led    Jeep      USA        Ahmed
# 4993  4994       C-51  02/03/2019         Rings   Honda    Japan       Yasser
# 4995  4996       A-28  03/08/2020   Front Light    Ford      USA       Yasser
# 4999  5000       U-22  19/01/2020      Back Led  Nissan    Japan        Amgad
#
# ...

# %%
data[(data['branch'] == "Cairo")]

# %%
data[(data['qty'] == 10)]
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 8        9       G-76  27/02/2019    Back Light  Toyota    Japan        Amgad
# 10      11       I-91  12/08/2020  Back Bumpers    Opel  Germany      Mostafa
# 13      14       X-66  24/08/2019      Body kit   Honda    Japan      Mostafa
# 46      47       X-66  22/11/2019      Back Led   Honda    Japan      Mostafa
# 63      64       P-81  31/10/2019      Spoilers    Audi  Germany      Mostafa
# ...    ...        ...         ...           ...     ...      ...          ...
# 4946  4947       F-67  22/11/2020      Back Fog    Ford      USA      Mostafa
# 4952  4953       W-59  29/01/2020          Logo  Nissan    Japan        Amgad
# 4973  4974       Z-65  25/10/2020  Front Bumper     BMW  Germany      Mohamed
# 4990  4991       V-51  27/05/2020  Back Bumpers    Opel  Germany        Amgad
# 4995  4996       A-28  03/08/2020   Front Light    Ford      USA       Yasser
#
# ...

# %%
data[(data['branch'] == "Cairo") & (data['qty'] == 10)]
# Out:
#       s/no invoice no        date       product  Brands  country sales Person  \
# 46      47       X-66  22/11/2019      Back Led   Honda    Japan      Mostafa
# 108    109       R-46  26/03/2019      Back Fog    Ford      USA        Amgad
# 129    130       P-26  21/09/2020  Back Bumpers   Mazda    Japan      Mohamed
# 146    147       H-80  14/07/2019  Back Bumpers   Mazda    Japan        Islam
# 166    167       F-31  10/05/2020    Back Light     BMW  Germany      Mohamed
# ...    ...        ...         ...           ...     ...      ...          ...
# 4742  4743       Q-47  27/11/2020    Back Light  Nissan    Japan        Ahmed
# 4753  4754       R-83  31/10/2020          Logo  Nissan    Japan        Ahmed
# 4781  4782       J-75  11/03/2020      Back Fog    Ford      USA        Amgad
# 4915  4916       A-21  29/05/2019  Back Bumpers  Nissan    Japan       Yasser
# 4995  4996       A-28  03/08/2020   Front Light    Ford      USA       Yasser
#
# ...

# %%
mydata = pd.read_csv(r"https://github.com/msnajjar/Panads-Files/raw/refs/heads/main/Cars1.csv")

# %%
mydata
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
euro12 = pd.read_csv('https://github.com/msnajjar/Panads-Files/raw/refs/heads/main/Euro_2012', sep=',')

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
#round(discipline['Yellow Cards'].mean())
round(discipline['Yellow Cards'].mean())
# Out:
# 7

# %%
euro12[euro12.Goals > 4]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 3    England      5               11                18             50.0%
# 5    Germany     10               32                32             47.8%
# 6     Greece      5                8                18             30.7%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 12    Russia      5                9                31             22.5%
# 13     Spain     12               42                33             55.9%
# 14    Sweden      5               17                19             47.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 3             17.2%                          40             0              0
# 5             15.6%                          80             2              1
# 6             19.2%                          32             1              1
# ...

# %%
euro12[euro12.Team == "Germany"]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
#
#    Players Used
# 5            17
#
# [1 rows x 35 columns]

# %%
euro12[euro12.Team.str.startswith("G") ]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
euro12[euro12.Team.str.endswith("e") ]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 4    France      3               22                24             37.9%
# 6    Greece      5                8                18             30.7%
# 15  Ukraine      2                7                26             21.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 4              6.5%                          65             1              0
# 6             19.2%                          32             1              1
# 15             6.0%                          38             0              0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 4                      0  ...           6                 54.6%         36
# 6                      1  ...          13                 65.1%         67
# 15                     0  ...          13                 76.5%         48
#
# ...

# %%
users = pd.read_table('https://github.com/msnajjar/Panads-Files/raw/refs/heads/main/user', 
                      sep='|', index_col='user_id')
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
users.groupby("occupation").age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
users.groupby("occupation").age.agg(["mean","max","min"])
# Out:
#                     mean  max  min
# occupation
# administrator  38.746835   70   21
# artist         31.392857   48   19
# doctor         43.571429   64   28
# educator       42.010526   63   23
# engineer       36.388060   70   22
# entertainment  29.222222   50   15
# executive      38.718750   69   22
# healthcare     41.562500   62   22
# homemaker      32.571429   50   20
# lawyer         36.750000   53   21
# librarian      40.000000   69   23
# marketing      37.615385   55   24
# none           26.555556   55   11
# other          34.523810   64   13
# programmer     33.121212   63   20
# retired        63.071429   73   51
# salesman       35.666667   66   18
# scientist      35.548387   55   23
# student        22.081633   42    7
# technician     33.148148   55   21
# writer         36.311111   60   18

# %%
users.groupby(["occupation","gender"]).age.agg(["mean","max","min","count"])
# Out:
#                            mean  max  min  count
# occupation    gender
# administrator F       40.638889   62   22     36
#               M       37.162791   70   21     43
# artist        F       30.307692   48   19     13
#               M       32.333333   45   20     15
# doctor        M       43.571429   64   28      7
# educator      F       39.115385   51   23     26
#               M       43.101449   63   25     69
# engineer      F       29.500000   36   23      2
#               M       36.600000   70   22     65
# entertainment F       31.000000   38   24      2
#               M       29.000000   50   15     16
# executive     F       44.000000   49   39      3
#               M       38.172414   69   22     29
# healthcare    F       39.818182   53   22     11
#               M       45.400000   62   28      5
# homemaker     F       34.166667   50   20      6
#               M       23.000000   23   23      1
# lawyer        F       39.500000   51   28      2
# ...

# %%
allsales = pd.read_csv(r"C:\000\eyouth\all_countries.csv")

# %%
allsales
# Out:
#         ProductID        Date Post_Code  Units   Revenue       Country
# 0             725   1/15/1999       H1B      1  120.2000         Egypt
# 1            2235   1/15/1999       H1B      2  131.1450         Egypt
# 2             713   1/15/1999       H1B      1  160.0725         Egypt
# 3             574  06/05/2002       H1B      1  869.1375         Egypt
# 4              94   2/15/1999       H1B      1  866.2500         Egypt
# ...           ...         ...       ...    ...       ...           ...
# 225950       2091   6/30/2015       L5N      1  183.6975  Saudi Arabia
# 225951       2186   6/30/2015       K1R      1  456.6975  Saudi Arabia
# 225952        993   6/30/2015       K1R      1  383.1975  Saudi Arabia
# 225953       1171   6/30/2015       R3E      1  356.9475  Saudi Arabia
# 225954      11111   6/30/2015       R3E      1  356.9475  Saudi Arabia
#
# [225955 rows x 6 columns]

# %%
eg_sales = pd.read_csv(r"C:\000\DATA Sets\International\International\Eg Sales.csv")
sa_sales = pd.read_csv(r"C:\000\DATA Sets\International\International\SA Sales.csv")
tn_sales = pd.read_csv(r"C:\000\DATA Sets\International\International\Tunisia Sales.csv")

# %%
eg_sales
# Out:
#        ProductID        Date Post_Code  Units   Revenue Country
# 0            725   1/15/1999       H1B      1  120.2000   Egypt
# 1           2235   1/15/1999       H1B      2  131.1450   Egypt
# 2            713   1/15/1999       H1B      1  160.0725   Egypt
# 3            574  06/05/2002       H1B      1  869.1375   Egypt
# 4             94   2/15/1999       H1B      1  866.2500   Egypt
# ...          ...         ...       ...    ...       ...     ...
# 75313       1009   6/30/2015       L5T      1  112.8225   Egypt
# 75314       2091   6/30/2015       L5N      1  183.6975   Egypt
# 75315       2186   6/30/2015       K1R      1  456.6975   Egypt
# 75316        993   6/30/2015       K1R      1  383.1975   Egypt
# 75317       1171   6/30/2015       R3E      1  356.9475   Egypt
#
# [75318 rows x 6 columns]

# %%
sa_sales
# Out:
#        ProductID       Date Post_Code  Units   Revenue       Country
# 0            725  1/15/1999       H1B      1  115.4475  Saudi Arabia
# 1           2235  1/15/1999       H1B      2  131.1450  Saudi Arabia
# 2            713  1/15/1999       H1B      1  160.0725  Saudi Arabia
# 3            574   6/5/2002       H1B      1  869.1375  Saudi Arabia
# 4             94  2/15/1999       H1B      1  866.2500  Saudi Arabia
# ...          ...        ...       ...    ...       ...           ...
# 75314       2091  6/30/2015       L5N      1  183.6975  Saudi Arabia
# 75315       2186  6/30/2015       K1R      1  456.6975  Saudi Arabia
# 75316        993  6/30/2015       K1R      1  383.1975  Saudi Arabia
# 75317       1171  6/30/2015       R3E      1  356.9475  Saudi Arabia
# 75318      11111  6/30/2015       R3E      1  356.9475  Saudi Arabia
#
# [75319 rows x 6 columns]

# %%
tn_sales
# Out:
#        ProductID        Date Post_Code  Units   Revenue  Country
# 0            725   1/15/1999       H1B      1  120.2000  Tunisia
# 1           2235   1/15/1999       H1B      2  131.1450  Tunisia
# 2            713   1/15/1999       H1B      1  160.0725  Tunisia
# 3            574  06/05/2002       H1B      1  869.1375  Tunisia
# 4             94   2/15/1999       H1B      1  866.2500  Tunisia
# ...          ...         ...       ...    ...       ...      ...
# 75313       1009   6/30/2015       L5T      1  112.8225  Tunisia
# 75314       2091   6/30/2015       L5N      1  183.6975  Tunisia
# 75315       2186   6/30/2015       K1R      1  456.6975  Tunisia
# 75316        993   6/30/2015       K1R      1  383.1975  Tunisia
# 75317       1171   6/30/2015       R3E      1  356.9475  Tunisia
#
# [75318 rows x 6 columns]

# %%
all_sales = eg_sales._append(sa_sales)

# %%
all_sales
# Out:
#        ProductID        Date Post_Code  Units   Revenue       Country
# 0            725   1/15/1999       H1B      1  120.2000         Egypt
# 1           2235   1/15/1999       H1B      2  131.1450         Egypt
# 2            713   1/15/1999       H1B      1  160.0725         Egypt
# 3            574  06/05/2002       H1B      1  869.1375         Egypt
# 4             94   2/15/1999       H1B      1  866.2500         Egypt
# ...          ...         ...       ...    ...       ...           ...
# 75314       2091   6/30/2015       L5N      1  183.6975  Saudi Arabia
# 75315       2186   6/30/2015       K1R      1  456.6975  Saudi Arabia
# 75316        993   6/30/2015       K1R      1  383.1975  Saudi Arabia
# 75317       1171   6/30/2015       R3E      1  356.9475  Saudi Arabia
# 75318      11111   6/30/2015       R3E      1  356.9475  Saudi Arabia
#
# [150637 rows x 6 columns]

# %%
allsales2 = all_sales._append(tn_sales)

# %%
allsales2
# Out:
#        ProductID        Date Post_Code  Units   Revenue  Country
# 0            725   1/15/1999       H1B      1  120.2000    Egypt
# 1           2235   1/15/1999       H1B      2  131.1450    Egypt
# 2            713   1/15/1999       H1B      1  160.0725    Egypt
# 3            574  06/05/2002       H1B      1  869.1375    Egypt
# 4             94   2/15/1999       H1B      1  866.2500    Egypt
# ...          ...         ...       ...    ...       ...      ...
# 75313       1009   6/30/2015       L5T      1  112.8225  Tunisia
# 75314       2091   6/30/2015       L5N      1  183.6975  Tunisia
# 75315       2186   6/30/2015       K1R      1  456.6975  Tunisia
# 75316        993   6/30/2015       K1R      1  383.1975  Tunisia
# 75317       1171   6/30/2015       R3E      1  356.9475  Tunisia
#
# [225955 rows x 6 columns]

# %%
car1 = pd.read_csv("https://github.com/msnajjar/Panads-Files/raw/refs/heads/main/Cars1.csv")

# %%
car1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
car2 = pd.read_csv("https://github.com/msnajjar/Panads-Files/raw/refs/heads/main/cars2.csv")

# %%
car2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %%
car1.shape
# Out:
# (198, 14)

# %%
car1._append(car2)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
# ...

# %%
columns_to_drop = ['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13']
car1 = car1.drop(columns=columns_to_drop, errors='ignore')

# %%
car1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
all_cars = car1._append(car2)

# %%
all_cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %%
import numpy as np
prices = np.random.randint(150000, 250000,398)

# %%
prices
# Out:
# array([200350, 230485, 181568, 158912, 199508, 185791, 152052, 230127,
#        194996, 163735, 155081, 223805, 235816, 229616, 157691, 179261,
#        213873, 207791, 238802, 177637, 174424, 204680, 164512, 183529,
#        215909, 239619, 192011, 183664, 200259, 232639, 212695, 213287,
#        152757, 158245, 237990, 221203, 160848, 204958, 207341, 198932,
#        198845, 205380, 198412, 166601, 228252, 191507, 241550, 202495,
#        177359, 163214, 248854, 219561, 151158, 240720, 164199, 155752,
#        167006, 211673, 160243, 177024, 223214, 244196, 215600, 189853,
#        212726, 215760, 196676, 200486, 192255, 233882, 230234, 186940,
#        154430, 173250, 151961, 233081, 169301, 203903, 248085, 185576,
#        186188, 240861, 230924, 203535, 205290, 223988, 200256, 201338,
#        179322, 247471, 195638, 166400, 222722, 188495, 244927, 221155,
#        178559, 186446, 158540, 247534, 151212, 225115, 187840, 240539,
# ...

# %%
all_cars['price'] = prices

# %%
all_cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car   price
# ...

# %%
edu = pd.read_csv(r"https://github.com/msnajjar/Panads-Files/raw/refs/heads/main/EducationLevel.csv")
edu
# Out:
#    EducationLevelID            EducationLevel
# 0                 1  No Formal Qualifications
# 1                 2              High School
# 2                 3                Bachelors
# 3                 4                  Masters
# 4                 5                 Doctorate

# %%
emp = pd.read_csv(r"https://github.com/msnajjar/Panads-Files/raw/refs/heads/main/Employee.csv")
emp
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State  Education  ...  \
# ...

# %%
full_emp = emp.merge(edu, left_on="Education", right_on="EducationLevelID")
full_emp = emp.merge(edu, left_on="Education", right_on="EducationLevelID")

# %%
full_emp
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State  Education  ...  \
# ...
